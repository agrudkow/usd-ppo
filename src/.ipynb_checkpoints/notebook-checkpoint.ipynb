# %% [markdown]
# # USD

# %% [markdown]
# ## Plot results

# %%
from os import path

from plot import make_plots

dir_path = path.abspath('')
results_dir = 'data'
make_plots(all_logdirs=[path.join(dir_path, '..',  results_dir, 'ppo-spinup-pyt-half-cheetah_halfcheetah-v2_gam0-89_cli0-1_tar0-01')])
# Out:
# Plotting from...
# ...
#
# /home/artur/Documents/weiti/mgr/usd-ppo/src/../data/ppo-spinup-pyt-half-cheetah_halfcheetah-v2_gam0-89_cli0-1_tar0-01
#
# ...
